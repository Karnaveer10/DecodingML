# %%
corpus ='''The quick brown fox jumps over the lazy dog near the river bank.
In the morning, the weather was cold and the sky was filled with clouds.
She is studying natural language processing at the university.
Data science is one of the fastest growing fields in the world today.
The teacher asked the students to submit their assignments on time.
He was reading a book while sitting on the chair by the window.
Artificial intelligence and machine learning are transforming the industry.
The city was built along the river and near the mountains.
They were discussing the impact of technology on modern education.
A good solution to the problem requires careful analysis and planning.
I went to the market to buy fruits and vegetables for the week.
The results of the experiment were recorded in the final report.
This project is focused on improving accuracy and performance.
Many people believe that practice is the key to success in life.
The company announced an increase in profit for the next quarter.
'''

# %%
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize,word_tokenize

import nltk 
nltk.download('stopwords')

nltk.download("punkt")
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Karnaveer
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Karnaveer
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Karnaveer
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Karnaveer
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
## need to download this for pos tagging
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Karnaveer Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
nltk.pos_tag(word_tokenize("Hello , hi my name is Karnaveer Singh"))
## expects list of words
# Out:
# [('Hello', 'NNP'),
#  (',', ','),
#  ('hi', 'VB'),
#  ('my', 'PRP$'),
#  ('name', 'NN'),
#  ('is', 'VBZ'),
#  ('Karnaveer', 'NNP'),
#  ('Singh', 'NNP')]

# %%
## Flow --> Applying Stop Words , Applying Lemmetization
import string
from nltk.stem import WordNetLemmatizer
lemm = WordNetLemmatizer()
sentences = sent_tokenize(corpus)

for i,sent in enumerate(sentences):

    filtered = [
        word.lower()
        for word in word_tokenize(sent)
        if word.lower() not in set(stopwords.words('english'))
        and word.lower() not in set(string.punctuation)
    ]
    lemmetized = [lemm.lemmatize(word,pos='v') for word in filtered]
    tagged = nltk.pos_tag(lemmetized)
    print(tagged)
# for sent in sentences:
#     filtered = [word for word in sent if word not in stopwords.words('english')]
# Out:
# [('quick', 'JJ'), ('brown', 'NN'), ('fox', 'JJ'), ('jump', 'NN'), ('lazy', 'NN'), ('dog', 'NN'), ('near', 'IN'), ('river', 'NN'), ('bank', 'NN')]
# [('morning', 'NN'), ('weather', 'NN'), ('cold', 'VBD'), ('sky', 'NN'), ('fill', 'NN'), ('cloud', 'NN')]
# [('study', 'NN'), ('natural', 'JJ'), ('language', 'NN'), ('process', 'NN'), ('university', 'NN')]
# [('data', 'NNS'), ('science', 'NN'), ('one', 'CD'), ('fastest', 'JJS'), ('grow', 'NN'), ('field', 'NN'), ('world', 'NN'), ('today', 'NN')]
# [('teacher', 'RB'), ('ask', 'JJ'), ('students', 'NNS'), ('submit', 'VBP'), ('assignments', 'NNS'), ('time', 'NN')]
# [('read', 'JJ'), ('book', 'NN'), ('sit', 'NN'), ('chair', 'NN'), ('window', 'NN')]
# [('artificial', 'JJ'), ('intelligence', 'NN'), ('machine', 'NN'), ('learn', 'VBP'), ('transform', 'NN'), ('industry', 'NN')]
# [('city', 'NN'), ('build', 'VB'), ('along', 'IN'), ('river', 'NN'), ('near', 'IN'), ('mountains', 'NNS')]
# ...

# %%
'''Word sense disambiguation: Resolves ambiguities (e.g., "bank" as noun for riverbank 
or verb for relying), enabling accurate comprehension of context.​

Dependency for advanced tasks: Serves as a foundation for named entity recognition 
(NER), parsing, and sentiment analysis by providing syntactic roles.​

Improved information extraction: Identifies key elements like subjects/objects, 
aiding tasks such as machine translation and text summarization.​

Sentence structure analysis: Reveals grammatical relationships, simplifying complex 
text into parseable components for deeper semantic understanding
'''
