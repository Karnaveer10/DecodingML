# %%
## we are going to use NLTK (natural language toolkit and spacy libraries)

# %%
## find difference between nltk and spacy

# %%
# !pip install nltk
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus = """Hello my name is karnaveer Singh.
I am trying out tokenization using open source libraries ,
such as NLTK and Spacy.

"""

# %%
corpus
# Out:
# 'Hello my name is karnaveer Singh.\nI am trying out tokenization using open source libraries ,\nsuch as NLTK and Spacy.\n\n'

# %%
import nltk
from nltk.tokenize import sent_tokenize

nltk.download("punkt")
nltk.download('punkt_tab')
text = "Hello! I am learning NLP. It is very interesting."
print(sent_tokenize(text))
# Out:
# ['Hello!', 'I am learning NLP.', 'It is very interesting.']
# [nltk_data] Downloading package punkt to C:\Users\Karnaveer
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Karnaveer
# [nltk_data]     Singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
sent_tokenize(corpus)
# Out:
# ['Hello my name is karnaveer Singh.',
#  'I am trying out tokenization using open source libraries ,\nsuch as NLTK and Spacy.']
